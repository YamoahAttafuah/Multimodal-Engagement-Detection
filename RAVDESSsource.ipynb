# %% [markdown]
# ## Training a 1d convolutional model on RAVDESS audio datasets
# We import the datasets and create pandas dataframes as in www.kaggle.com/code/llhvglbmlf/capstone-aiml.
#
# Samples labelled as 'surprised' or label 8 are dropped as they serve no useful purpose in this case.
#
# We end up with 2260 samples, data is given by a filepath and a binary 0 (positive affect) or 1 (negative affect) label.

# %%
# adapated from https://www.kaggle.com/datasets/uwrfkaggler/ravdess-emotional-speech-audio/data
import kagglehub, librosa, tensorflow as tf
import os, pandas as pd, matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split
from tensorflow import keras
from tensorflow.keras.layers import (Conv1D,BatchNormalization, Dropout, Flatten, Dense, Input,GlobalAveragePooling1D, MaxPool1D)
from tensorflow.keras import initializers, layers, models

path = kagglehub.dataset_download("uwrfkaggler/ravdess-emotional-speech-audio")
path2 = kagglehub.dataset_download("uwrfkaggler/ravdess-emotional-song-audio")

# adapated from https://www.kaggle.com/code/llhvglbmlf/capstone-aiml
F, L = [], []

# parse the paths and file names for emotion identifiers
for dirname, _, filenames in os.walk(path):
    for filename in filenames:
        label = filename[::-1].split('_')[0][::-1]
        k=int(label[7:8])
        if k!=8:
            F.append(os.path.join(dirname, filename))
            if k<=3:
                L.append(0)
            else:
                L.append(1)

for dirname, _, filenames in os.walk(path2):
    for filename in filenames:
        label = filename[::+-1].split('_')[0][::-1]
        k=int(label[7:8])
        if k!=8:
            F.append(os.path.join(dirname, filename))
            if k<=3:
                L.append(0)
            else:
                L.append(1)
        
data=pd.DataFrame({'files':F, 'labels':L})
classes=['positive','negative']

# now we have one numpy array containing the paths and their labels
full=np.array((data.files,data.labels)).T
Labels=np.ascontiguousarray(full.T[1],dtype=np.int32)

print(full.shape)
print(Labels.shape)
# Out:
# (2260, 2)
# (2260,)

# %% [markdown]
# ## Waveform visualization
#
# The following waveform depictions are included to display the original intent of the training: we wanted to train a 2d convolutional model on the images of these waveforms, but this did not work out.

# %%
# let's see a few examples of waveforms

fig, axs = plt.subplots(nrows=1, ncols=4, figsize=(16,4))
l=22050

for i in range(4):
    audio,label=full[i*100]
    y, sr = librosa.load(audio, sr=l)
    X = librosa.times_like(y)
    axs[i].plot(X, y)
    axs[i].set_title(classes[label])
    axs[i].set_xlabel('milliseconds')
    axs[i].set_ylabel('frequency')

# %% [markdown]
# ## Feature extraction
#
# Using librosa, we parse each sample for its audio features using a 5 second duration and 22.05 kHz sampling rate.
#
# Due to the small size of the dataset, we take an 80-10-10 train-val-test split. There is a slight class imbalance favouring the negative samples, but this is reflected in both train and validation splits. It is also expected since the neutral emotion had fewer samples in the dataset, and we assigned neutral to the positive affect.

# %%
sr=22050
dur=5
clip_len=dur*sr

audio_features=[]
targets=[]

dataset_paths=full.T[0]
labels=full.T[1]

for file,label in zip(dataset_paths,labels):
    audio, sr = librosa.load(file, sr=22050, mono=True)
    audio = audio / (np.max(np.abs(audio)) + 1e-6)

    if len(audio)<clip_len:
        audio=np.pad(audio,(0,clip_len-len(audio)))
    else:
        audio=audio[:clip_len]
    
    audio_features.append(audio)
    targets.append(label)
    
audio_features,targets=np.array(audio_features),np.array(targets)

audio_features=audio_features.reshape(len(labels),sr*dur,1)

train_data,test_data,train_labels,test_labels=train_test_split(audio_features,targets,test_size=0.2)
val_data,test_data,val_labels,test_labels=train_test_split(test_data,test_labels,test_size=0.5)

# slight class imbalance favouring negative samples
print('Train split class distribution:', np.bincount(train_labels.astype(int)))
print'Val split class distribution:', np.bincount(val_labels.astype(int)))
# Out:
# Train class distribution: [ 760 1048]
# Val class distribution: [ 94 132]

# %% [markdown]
# ## Training
#
# Using tensorflow, we train a relatively simple 1d convolutional model with 3 convolutional blocks, one linear layer, ending with a single sigmoid-activated neuron. Practically, we can interpret the output of the model as a confidence/likelihood that the observed sample belongs to label 1: negative. Thus we can consider 100-prediction to be a confidence/likelihood that the observed sample belongs to label 0: positive. The raw output of thismodel is effectively a negative emotion predictor.
#
# Note that we choose an unaltered Adam lr 0.001 optimizer and a binary cross entropy loss. We also record all metrics, including a checkpoint callback. We do not include an early stop callback for the purpose of visualizing the when the model begins to overfit.

# %%
model = keras.Sequential([
    Input((clip_len, 1)),
    Conv1D(16,60,2,padding='same',activation='relu'),
    keras.layers.MaxPool1D(4),
    keras.layers.Dropout(0.2),

    keras.layers.Conv1D(32,16,2,padding='same',activation='relu'),
    keras.layers.MaxPool1D(4),
    keras.layers.Dropout(0.2),
    
    keras.layers.Conv1D(64,8,2,padding='same',activation='relu'),
    keras.layers.BatchNormalization(),
    keras.layers.MaxPool1D(4),
    
    keras.layers.GlobalAveragePooling1D(),
    keras.layers.Dense(60, activation='relu'),
    keras.layers.Dropout(0.4),
    keras.layers.Dense(1, activation='sigmoid')])

model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])
model.summary()

checkpoint = keras.callbacks.ModelCheckpoint(
    filepath='audio1dconv.keras',
    monitor='val_loss',
    save_best_only=True,
    mode='min',
    verbose=1)

history=model.fit(
    x=train_data,
    y=train_labels,
    validation_data=(val_data,val_labels),
    epochs=60,
    batch_size=16,
    callbacks=checkpoint)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_6 (Conv1D)           (None, 55125, 16)         976
#
#  max_pooling1d_6 (MaxPoolin  (None, 13781, 16)         0
#  g1D)
#
#  dropout_6 (Dropout)         (None, 13781, 16)         0
#
#  conv1d_7 (Conv1D)           (None, 6891, 32)          8224
#
#  max_pooling1d_7 (MaxPoolin  (None, 1722, 32)          0
#  g1D)
#
#  dropout_7 (Dropout)         (None, 1722, 32)          0
#
#  conv1d_8 (Conv1D)           (None, 861, 64)           16448
#
#  batch_normalization (Batch  (None, 861, 64)           256
#  Normalization)
#
#  max_pooling1d_8 (MaxPoolin  (None, 215, 64)           0
#  g1D)
#
#  global_average_pooling1d_2  (None, 64)                0
#   (GlobalAveragePooling1D)
#
#  dense_4 (Dense)             (None, 60)                3900
#
#  dropout_8 (Dropout)         (None, 60)                0
#
#  dense_5 (Dense)             (None, 1)                 61
#
# =================================================================
# Total params: 29865 (116.66 KB)
# Trainable params: 29737 (116.16 KB)
# Non-trainable params: 128 (512.00 Byte)
# _________________________________________________________________
# Epoch 1/60
# 113/113 [==============================] - ETA: 0s - loss: 0.6631 - accuracy: 0.6067
# Epoch 1: val_loss improved from inf to 0.67346, saving model to audio1dconv.keras
# 113/113 [==============================] - 11s 90ms/step - loss: 0.6631 - accuracy: 0.6067 - val_loss: 0.6735 - val_accuracy: 0.6150
# Epoch 2/60
# 113/113 [==============================] - ETA: 0s - loss: 0.6378 - accuracy: 0.6532
# Epoch 2: val_loss improved from 0.67346 to 0.65273, saving model to audio1dconv.keras
# 113/113 [==============================] - 11s 93ms/step - loss: 0.6378 - accuracy: 0.6532 - val_loss: 0.6527 - val_accuracy: 0.6637
# Epoch 3/60
# 113/113 [==============================] - ETA: 0s - loss: 0.6031 - accuracy: 0.6831
# Epoch 3: val_loss improved from 0.65273 to 0.61211, saving model to audio1dconv.keras
# 113/113 [==============================] - 13s 114ms/step - loss: 0.6031 - accuracy: 0.6831 - val_loss: 0.6121 - val_accuracy: 0.7212
# Epoch 4/60
# 113/113 [==============================] - ETA: 0s - loss: 0.5748 - accuracy: 0.7058
# Epoch 4: val_loss improved from 0.61211 to 0.57670, saving model to audio1dconv.keras
# 113/113 [==============================] - 12s 106ms/step - loss: 0.5748 - accuracy: 0.7058 - val_loss: 0.5767 - val_accuracy: 0.7257
# Epoch 5/60
# 113/113 [==============================] - ETA: 0s - loss: 0.5594 - accuracy: 0.7163
# Epoch 5: val_loss improved from 0.57670 to 0.55326, saving model to audio1dconv.keras
# 113/113 [==============================] - 13s 112ms/step - loss: 0.5594 - accuracy: 0.7163 - val_loss: 0.5533 - val_accuracy: 0.7168
# Epoch 6/60
# 113/113 [==============================] - ETA: 0s - loss: 0.5005 - accuracy: 0.7522
# Epoch 6: val_loss did not improve from 0.55326
# 113/113 [==============================] - 14s 125ms/step - loss: 0.5005 - accuracy: 0.7522 - val_loss: 0.5868 - val_accuracy: 0.6814
# Epoch 7/60
# 113/113 [==============================] - ETA: 0s - loss: 0.4883 - accuracy: 0.7649
# Epoch 7: val_loss improved from 0.55326 to 0.44970, saving model to audio1dconv.keras
# 113/113 [==============================] - 14s 126ms/step - loss: 0.4883 - accuracy: 0.7649 - val_loss: 0.4497 - val_accuracy: 0.7876
# Epoch 8/60
# 113/113 [==============================] - ETA: 0s - loss: 0.4705 - accuracy: 0.7887
# Epoch 8: val_loss did not improve from 0.44970
# 113/113 [==============================] - 15s 129ms/step - loss: 0.4705 - accuracy: 0.7887 - val_loss: 0.6578 - val_accuracy: 0.7035
# Epoch 9/60
# 113/113 [==============================] - ETA: 0s - loss: 0.4383 - accuracy: 0.7926
# Epoch 9: val_loss did not improve from 0.44970
# 113/113 [==============================] - 14s 126ms/step - loss: 0.4383 - accuracy: 0.7926 - val_loss: 0.5532 - val_accuracy: 0.6504
# Epoch 10/60
# 113/113 [==============================] - ETA: 0s - loss: 0.3986 - accuracy: 0.8263
# Epoch 10: val_loss improved from 0.44970 to 0.39305, saving model to audio1dconv.keras
# 113/113 [==============================] - 15s 132ms/step - loss: 0.3986 - accuracy: 0.8263 - val_loss: 0.3931 - val_accuracy: 0.8186
# Epoch 11/60
# 113/113 [==============================] - ETA: 0s - loss: 0.3936 - accuracy: 0.8136
# Epoch 11: val_loss did not improve from 0.39305
# 113/113 [==============================] - 15s 129ms/step - loss: 0.3936 - accuracy: 0.8136 - val_loss: 0.4154 - val_accuracy: 0.7920
# Epoch 12/60
# 113/113 [==============================] - ETA: 0s - loss: 0.3767 - accuracy: 0.8241
# Epoch 12: val_loss did not improve from 0.39305
# 113/113 [==============================] - 15s 130ms/step - loss: 0.3767 - accuracy: 0.8241 - val_loss: 0.5145 - val_accuracy: 0.7345
# Epoch 13/60
# 113/113 [==============================] - ETA: 0s - loss: 0.3756 - accuracy: 0.8285
# Epoch 13: val_loss improved from 0.39305 to 0.37165, saving model to audio1dconv.keras
# 113/113 [==============================] - 14s 123ms/step - loss: 0.3756 - accuracy: 0.8285 - val_loss: 0.3717 - val_accuracy: 0.8319
# Epoch 14/60
# 113/113 [==============================] - ETA: 0s - loss: 0.3553 - accuracy: 0.8413
# Epoch 14: val_loss did not improve from 0.37165
# 113/113 [==============================] - 14s 123ms/step - loss: 0.3553 - accuracy: 0.8413 - val_loss: 0.4765 - val_accuracy: 0.7478
# Epoch 15/60
# 113/113 [==============================] - ETA: 0s - loss: 0.3573 - accuracy: 0.8407
# Epoch 15: val_loss did not improve from 0.37165
# 113/113 [==============================] - 14s 124ms/step - loss: 0.3573 - accuracy: 0.8407 - val_loss: 0.4789 - val_accuracy: 0.7611
# Epoch 16/60
# 113/113 [==============================] - ETA: 0s - loss: 0.3355 - accuracy: 0.8579
# Epoch 16: val_loss did not improve from 0.37165
# 113/113 [==============================] - 14s 122ms/step - loss: 0.3355 - accuracy: 0.8579 - val_loss: 0.5729 - val_accuracy: 0.7566
# Epoch 17/60
# 113/113 [==============================] - ETA: 0s - loss: 0.3510 - accuracy: 0.8407
# Epoch 17: val_loss did not improve from 0.37165
# 113/113 [==============================] - 14s 123ms/step - loss: 0.3510 - accuracy: 0.8407 - val_loss: 0.5176 - val_accuracy: 0.7168
# Epoch 18/60
# 113/113 [==============================] - ETA: 0s - loss: 0.3434 - accuracy: 0.8512
# Epoch 18: val_loss improved from 0.37165 to 0.36231, saving model to audio1dconv.keras
# 113/113 [==============================] - 14s 124ms/step - loss: 0.3434 - accuracy: 0.8512 - val_loss: 0.3623 - val_accuracy: 0.8186
# Epoch 19/60
# 113/113 [==============================] - ETA: 0s - loss: 0.3209 - accuracy: 0.8634
# Epoch 19: val_loss did not improve from 0.36231
# 113/113 [==============================] - 14s 126ms/step - loss: 0.3209 - accuracy: 0.8634 - val_loss: 0.4150 - val_accuracy: 0.8186
# Epoch 20/60
# 113/113 [==============================] - ETA: 0s - loss: 0.3291 - accuracy: 0.8556
# Epoch 20: val_loss did not improve from 0.36231
# 113/113 [==============================] - 14s 123ms/step - loss: 0.3291 - accuracy: 0.8556 - val_loss: 0.6660 - val_accuracy: 0.6460
# Epoch 21/60
# 113/113 [==============================] - ETA: 0s - loss: 0.3052 - accuracy: 0.8590
# Epoch 21: val_loss did not improve from 0.36231
# 113/113 [==============================] - 14s 123ms/step - loss: 0.3052 - accuracy: 0.8590 - val_loss: 0.5214 - val_accuracy: 0.7788
# Epoch 22/60
# 113/113 [==============================] - ETA: 0s - loss: 0.3034 - accuracy: 0.8711
# Epoch 22: val_loss did not improve from 0.36231
# 113/113 [==============================] - 14s 123ms/step - loss: 0.3034 - accuracy: 0.8711 - val_loss: 0.6996 - val_accuracy: 0.7566
# Epoch 23/60
# 113/113 [==============================] - ETA: 0s - loss: 0.3155 - accuracy: 0.8645
# Epoch 23: val_loss improved from 0.36231 to 0.33031, saving model to audio1dconv.keras
# 113/113 [==============================] - 14s 124ms/step - loss: 0.3155 - accuracy: 0.8645 - val_loss: 0.3303 - val_accuracy: 0.8451
# Epoch 24/60
# 113/113 [==============================] - ETA: 0s - loss: 0.3060 - accuracy: 0.8756
# Epoch 24: val_loss did not improve from 0.33031
# 113/113 [==============================] - 14s 122ms/step - loss: 0.3060 - accuracy: 0.8756 - val_loss: 0.4511 - val_accuracy: 0.7566
# Epoch 25/60
# 113/113 [==============================] - ETA: 0s - loss: 0.2977 - accuracy: 0.8722
# Epoch 25: val_loss did not improve from 0.33031
# 113/113 [==============================] - 14s 122ms/step - loss: 0.2977 - accuracy: 0.8722 - val_loss: 0.3906 - val_accuracy: 0.8319
# Epoch 26/60
# 113/113 [==============================] - ETA: 0s - loss: 0.2871 - accuracy: 0.8800
# Epoch 26: val_loss did not improve from 0.33031
# 113/113 [==============================] - 14s 125ms/step - loss: 0.2871 - accuracy: 0.8800 - val_loss: 0.4268 - val_accuracy: 0.8230
# Epoch 27/60
# 113/113 [==============================] - ETA: 0s - loss: 0.2769 - accuracy: 0.8805
# Epoch 27: val_loss did not improve from 0.33031
# 113/113 [==============================] - 14s 122ms/step - loss: 0.2769 - accuracy: 0.8805 - val_loss: 0.3761 - val_accuracy: 0.8230
# Epoch 28/60
# 113/113 [==============================] - ETA: 0s - loss: 0.2776 - accuracy: 0.8750
# Epoch 28: val_loss did not improve from 0.33031
# 113/113 [==============================] - 14s 123ms/step - loss: 0.2776 - accuracy: 0.8750 - val_loss: 0.4162 - val_accuracy: 0.8496
# Epoch 29/60
# 113/113 [==============================] - ETA: 0s - loss: 0.2768 - accuracy: 0.8767
# Epoch 29: val_loss improved from 0.33031 to 0.30852, saving model to audio1dconv.keras
# 113/113 [==============================] - 14s 125ms/step - loss: 0.2768 - accuracy: 0.8767 - val_loss: 0.3085 - val_accuracy: 0.8628
# Epoch 30/60
# 113/113 [==============================] - ETA: 0s - loss: 0.2766 - accuracy: 0.8883
# Epoch 30: val_loss did not improve from 0.30852
# 113/113 [==============================] - 14s 123ms/step - loss: 0.2766 - accuracy: 0.8883 - val_loss: 0.3538 - val_accuracy: 0.8496
# Epoch 31/60
# 113/113 [==============================] - ETA: 0s - loss: 0.2819 - accuracy: 0.8783
# Epoch 31: val_loss did not improve from 0.30852
# 113/113 [==============================] - 14s 122ms/step - loss: 0.2819 - accuracy: 0.8783 - val_loss: 1.4580 - val_accuracy: 0.6460
# Epoch 32/60
# 113/113 [==============================] - ETA: 0s - loss: 0.2583 - accuracy: 0.8944
# Epoch 32: val_loss did not improve from 0.30852
# 113/113 [==============================] - 14s 127ms/step - loss: 0.2583 - accuracy: 0.8944 - val_loss: 0.3272 - val_accuracy: 0.8496
# Epoch 33/60
# 113/113 [==============================] - ETA: 0s - loss: 0.2708 - accuracy: 0.8861
# Epoch 33: val_loss did not improve from 0.30852
# 113/113 [==============================] - 14s 122ms/step - loss: 0.2708 - accuracy: 0.8861 - val_loss: 0.4912 - val_accuracy: 0.7743
# Epoch 34/60
# 113/113 [==============================] - ETA: 0s - loss: 0.2309 - accuracy: 0.9043
# Epoch 34: val_loss did not improve from 0.30852
# 113/113 [==============================] - 14s 127ms/step - loss: 0.2309 - accuracy: 0.9043 - val_loss: 0.4185 - val_accuracy: 0.8230
# Epoch 35/60
# 113/113 [==============================] - ETA: 0s - loss: 0.2354 - accuracy: 0.9004
# Epoch 35: val_loss did not improve from 0.30852
# 113/113 [==============================] - 14s 125ms/step - loss: 0.2354 - accuracy: 0.9004 - val_loss: 0.5725 - val_accuracy: 0.7566
# Epoch 36/60
# 113/113 [==============================] - ETA: 0s - loss: 0.2197 - accuracy: 0.9032
# Epoch 36: val_loss did not improve from 0.30852
# 113/113 [==============================] - 14s 125ms/step - loss: 0.2197 - accuracy: 0.9032 - val_loss: 0.3612 - val_accuracy: 0.8407
# Epoch 37/60
# 113/113 [==============================] - ETA: 0s - loss: 0.2307 - accuracy: 0.8999
# Epoch 37: val_loss did not improve from 0.30852
# 113/113 [==============================] - 15s 132ms/step - loss: 0.2307 - accuracy: 0.8999 - val_loss: 1.0136 - val_accuracy: 0.6770
# Epoch 38/60
# 113/113 [==============================] - ETA: 0s - loss: 0.2397 - accuracy: 0.8988
# Epoch 38: val_loss did not improve from 0.30852
# 113/113 [==============================] - 15s 129ms/step - loss: 0.2397 - accuracy: 0.8988 - val_loss: 0.6535 - val_accuracy: 0.7832
# Epoch 39/60
# 113/113 [==============================] - ETA: 0s - loss: 0.2194 - accuracy: 0.9154
# Epoch 39: val_loss did not improve from 0.30852
# 113/113 [==============================] - 14s 121ms/step - loss: 0.2194 - accuracy: 0.9154 - val_loss: 0.6096 - val_accuracy: 0.6858
# Epoch 40/60
# 113/113 [==============================] - ETA: 0s - loss: 0.2102 - accuracy: 0.9110
# Epoch 40: val_loss did not improve from 0.30852
# 113/113 [==============================] - 14s 128ms/step - loss: 0.2102 - accuracy: 0.9110 - val_loss: 0.3337 - val_accuracy: 0.8363
# Epoch 41/60
# 113/113 [==============================] - ETA: 0s - loss: 0.2069 - accuracy: 0.9204
# Epoch 41: val_loss did not improve from 0.30852
# 113/113 [==============================] - 14s 125ms/step - loss: 0.2069 - accuracy: 0.9204 - val_loss: 0.6211 - val_accuracy: 0.7212
# Epoch 42/60
# 113/113 [==============================] - ETA: 0s - loss: 0.2303 - accuracy: 0.9054
# Epoch 42: val_loss did not improve from 0.30852
# 113/113 [==============================] - 15s 134ms/step - loss: 0.2303 - accuracy: 0.9054 - val_loss: 0.3580 - val_accuracy: 0.8319
# Epoch 43/60
# 113/113 [==============================] - ETA: 0s - loss: 0.1997 - accuracy: 0.9209
# Epoch 43: val_loss did not improve from 0.30852
# 113/113 [==============================] - 14s 125ms/step - loss: 0.1997 - accuracy: 0.9209 - val_loss: 0.3526 - val_accuracy: 0.8496
# Epoch 44/60
# 113/113 [==============================] - ETA: 0s - loss: 0.2399 - accuracy: 0.9004
# Epoch 44: val_loss did not improve from 0.30852
# 113/113 [==============================] - 14s 126ms/step - loss: 0.2399 - accuracy: 0.9004 - val_loss: 0.3578 - val_accuracy: 0.8319
# Epoch 45/60
# 113/113 [==============================] - ETA: 0s - loss: 0.2041 - accuracy: 0.9198
# Epoch 45: val_loss did not improve from 0.30852
# 113/113 [==============================] - 14s 125ms/step - loss: 0.2041 - accuracy: 0.9198 - val_loss: 0.4008 - val_accuracy: 0.8451
# Epoch 46/60
# 113/113 [==============================] - ETA: 0s - loss: 0.2137 - accuracy: 0.9143
# Epoch 46: val_loss did not improve from 0.30852
# 113/113 [==============================] - 14s 122ms/step - loss: 0.2137 - accuracy: 0.9143 - val_loss: 0.3193 - val_accuracy: 0.8673
# Epoch 47/60
# 113/113 [==============================] - ETA: 0s - loss: 0.2009 - accuracy: 0.9170
# Epoch 47: val_loss did not improve from 0.30852
# 113/113 [==============================] - 15s 131ms/step - loss: 0.2009 - accuracy: 0.9170 - val_loss: 1.3380 - val_accuracy: 0.7257
# Epoch 48/60
# 113/113 [==============================] - ETA: 0s - loss: 0.2257 - accuracy: 0.9104
# Epoch 48: val_loss did not improve from 0.30852
# 113/113 [==============================] - 14s 121ms/step - loss: 0.2257 - accuracy: 0.9104 - val_loss: 0.4476 - val_accuracy: 0.8009
# Epoch 49/60
# 113/113 [==============================] - ETA: 0s - loss: 0.1684 - accuracy: 0.9331
# Epoch 49: val_loss did not improve from 0.30852
# 113/113 [==============================] - 14s 122ms/step - loss: 0.1684 - accuracy: 0.9331 - val_loss: 0.3669 - val_accuracy: 0.8540
# Epoch 50/60
# 113/113 [==============================] - ETA: 0s - loss: 0.1720 - accuracy: 0.9270
# Epoch 50: val_loss did not improve from 0.30852
# 113/113 [==============================] - 14s 123ms/step - loss: 0.1720 - accuracy: 0.9270 - val_loss: 0.6812 - val_accuracy: 0.6637
# Epoch 51/60
# 113/113 [==============================] - ETA: 0s - loss: 0.1534 - accuracy: 0.9430
# Epoch 51: val_loss did not improve from 0.30852
# 113/113 [==============================] - 14s 123ms/step - loss: 0.1534 - accuracy: 0.9430 - val_loss: 0.7332 - val_accuracy: 0.7655
# Epoch 52/60
# 113/113 [==============================] - ETA: 0s - loss: 0.1843 - accuracy: 0.9253
# Epoch 52: val_loss did not improve from 0.30852
# 113/113 [==============================] - 14s 124ms/step - loss: 0.1843 - accuracy: 0.9253 - val_loss: 0.3271 - val_accuracy: 0.8673
# Epoch 53/60
# 113/113 [==============================] - ETA: 0s - loss: 0.1800 - accuracy: 0.9248
# Epoch 53: val_loss did not improve from 0.30852
# 113/113 [==============================] - 14s 125ms/step - loss: 0.1800 - accuracy: 0.9248 - val_loss: 0.6194 - val_accuracy: 0.7389
# Epoch 54/60
# 113/113 [==============================] - ETA: 0s - loss: 0.1728 - accuracy: 0.9369
# Epoch 54: val_loss did not improve from 0.30852
# 113/113 [==============================] - 14s 124ms/step - loss: 0.1728 - accuracy: 0.9369 - val_loss: 2.3542 - val_accuracy: 0.5000
# Epoch 55/60
# 113/113 [==============================] - ETA: 0s - loss: 0.1531 - accuracy: 0.9358
# Epoch 55: val_loss did not improve from 0.30852
# 113/113 [==============================] - 14s 123ms/step - loss: 0.1531 - accuracy: 0.9358 - val_loss: 0.5387 - val_accuracy: 0.8230
# Epoch 56/60
# 113/113 [==============================] - ETA: 0s - loss: 0.1526 - accuracy: 0.9425
# Epoch 56: val_loss did not improve from 0.30852
# 113/113 [==============================] - 14s 126ms/step - loss: 0.1526 - accuracy: 0.9425 - val_loss: 0.3773 - val_accuracy: 0.8363
# Epoch 57/60
# 113/113 [==============================] - ETA: 0s - loss: 0.1794 - accuracy: 0.9309
# Epoch 57: val_loss did not improve from 0.30852
# 113/113 [==============================] - 14s 124ms/step - loss: 0.1794 - accuracy: 0.9309 - val_loss: 0.3334 - val_accuracy: 0.8496
# Epoch 58/60
# 113/113 [==============================] - ETA: 0s - loss: 0.1451 - accuracy: 0.9397
# Epoch 58: val_loss did not improve from 0.30852
# 113/113 [==============================] - 14s 125ms/step - loss: 0.1451 - accuracy: 0.9397 - val_loss: 0.4114 - val_accuracy: 0.8451
# Epoch 59/60
# 113/113 [==============================] - ETA: 0s - loss: 0.1463 - accuracy: 0.9441
# Epoch 59: val_loss did not improve from 0.30852
# 113/113 [==============================] - 14s 123ms/step - loss: 0.1463 - accuracy: 0.9441 - val_loss: 0.3448 - val_accuracy: 0.8805
# Epoch 60/60
# 113/113 [==============================] - ETA: 0s - loss: 0.1553 - accuracy: 0.9386
# Epoch 60: val_loss did not improve from 0.30852
# 113/113 [==============================] - 14s 122ms/step - loss: 0.1553 - accuracy: 0.9386 - val_loss: 2.6165 - val_accuracy: 0.4646

# %%
fig,axs=plt.subplots(nrows=1,ncols=2,figsize=(9,5))

axs[0].plot([i for i in range(60)],history.history['loss'],label='training accuracy')
axs[0].plot([i for i in range(60)],history.history['val_loss'],label='validation accuracy')
axs[0].set_title('Loss curves for BS=16, Adam LR=0.001')
axs[0].legend()
axs[1].plot([i for i in range(60)],history.history['accuracy'],label='training accuracy')
axs[1].plot([i for i in range(60)],history.history['val_accuracy'],label='validation accuracy')
axs[1].set_title('Accuracy curves for BS=16, Adam LR=0.001')
axs[1].legend()
